# %%
from bs4 import BeautifulSoup
import requests

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
soup = BeautifulSoup(html_doc, 'html.parser')

print(soup.prettify())
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link2">
#     Tillie
#    </a>
#    ; and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
print(soup.title)
print("''''''''''''''''''''''")
# <title>The Dormouse's story</title>

print(soup.title.name)
print("''''''''''''''''''''''")
# u'title'

print(soup.title.string)
print("''''''''''''''''''''''")
# u'The Dormouse's story'

print(soup.title.parent.name)
print("''''''''''''''''''''''")
# u'head'

print(soup.p)
print("''''''''''''''''''''''")
# <p class="title"><b>The Dormouse's story</b></p>

print(soup.p['class'])
print("''''''''''''''''''''''")
# u'title'

print(soup.a)
print("''''''''''''''''''''''")
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

print(soup.find_all('a'))
print("''''''''''''''''''''''")
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

print(soup.find(id="link3"))
print("''''''''''''''''''''''")
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# Out:
# <title>The Dormouse's story</title>
# ''''''''''''''''''''''
# title
# ''''''''''''''''''''''
# The Dormouse's story
# ''''''''''''''''''''''
# head
# ''''''''''''''''''''''
# <p class="title"><b>The Dormouse's story</b></p>
# ''''''''''''''''''''''
# ['title']
# ''''''''''''''''''''''
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# ''''''''''''''''''''''
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
# ''''''''''''''''''''''
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# ''''''''''''''''''''''

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
print(soup.get_text())
# Out:
# The Dormouse's story
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
html = requests.get("https://www.songkick.com/artists/5607218-isaiah-rashad")
soup = BeautifulSoup(html.text, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head prefix="og: http://ogp.me/ns# fb: http://www.facebook.com/2008/fbml songkick-concerts: http://ogp.me/ns/fb/songkick-concerts#">
#   <link href="//assets.sk-static.com/assets/stylesheets/artist.8d9fee3da837608a7ba8.css" rel="stylesheet" type="text/css"/>
#   <script type="text/javascript">
#    SK = typeof(SK) == 'undefined' ? {} : SK;
#   SK_ASSET_HOST = "//assets.sk-static.com";
#   SK_DYNAMIC_ASSET_HOST = "https://images.sk-static.com";
#   CX_EXPERIMENT_ID = "";
#   CX_VARIATION_ID = -2;
#   </script>
#   <script src="//assets.sk-static.com/assets/Songkick.918ceb615381e59308e1.js" type="text/javascript">
#   </script>
#   <title>
#    Isaiah Rashad Tour Dates, Concerts &amp; Tickets – Songkick
#   </title>
#   <link href="https://fonts.googleapis.com/css?family=Biryani:400,900" rel="stylesheet"/>
#   <link href="//images.sk-static.com/images/media/img/col4/20161219-212405-399135.jpg" rel="image_src"/>
#   <link href="//assets.sk-static.com/images/favicon.ico" rel="shortcut icon" type="image/x-icon">
#    <link href="//assets.sk-static.com/images/apple-touch-icon.png" rel="apple-touch-icon"/>
#    <link href="//assets.sk-static.com/images/apple-touch-icon.png" rel="apple-touch-icon-precomposed"/>
#    <meta content="all" name="robots"/>
#    <link href="https://www.songkick.com/artists/5607218-isaiah-rashad" rel="canonical"/>
#    <meta content="songkick://artists/5607218-isaiah-rashad" property="al:ios:url"/>
#    <meta content="438690886" property="al:ios:app_store_id"/>
#    <meta content="Songkick Concerts" property="al:ios:app_name"/>
#    <meta content="Find out when Isaiah Rashad is next playing live near you. List of all Isaiah Rashad tour dates and concerts." name="description"/>
#    <meta content="308540029359" property="fb:app_id"/>
#    <meta content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, width=device-width" name="viewport"/>
#    <meta content="yes" name="apple-mobile-web-app-capable"/>
#    <meta content="Songkick" property="og:site_name"/>
#    <meta content="songkick-concerts:artist" property="og:type"/>
#    <meta content="Isaiah Rashad" property="og:title"/>
#    <meta content="Find out when Isaiah Rashad is next playing live near you. List of all Isaiah Rashad tour dates and concerts." property="og:description"/>
#    <meta content="https://www.songkick.com/artists/5607218-isaiah-rashad" property="og:url"/>
#    <meta content="http://images.sk-static.com/images/media/img/col4/20161219-212405-399135.jpg" property="og:image"/>
#   </link>
#  </head>
#  <body>
#   <script>
#    !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#   n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#   document,'script','//connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '583609881778767');
#   fbq('track', 'PageView');
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://www.facebook.com/tr?id=583609881778767&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <script>
#    var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "8430760" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#   </script>
#   <noscript>
#    <img alt="" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=8430760&amp;cv=2.0&amp;cj=1"/>
#   </noscript>
#   <div id="fb-root">
#   </div>
#   <div class="track-alert js-track-alert ">
#    <div class="track-alert-inner">
#     This event has been added to your
#     <a data-analytics-category="navigation_your_plans" data-analytics-label="feedback_your_plans" href="/calendar?filter=attendance">
#      Plans
#     </a>
#     .
#    </div>
#   </div>
#   <div class="navigation navigation-wrapper">
#    <div class="navigation-large-screen">
#     <ul class="nav-bar">
#      <li class="sub-nav">
#       <ul>
#        <li class="logo">
#         <a data-analytics-category="navigation" data-analytics-label="logo" href="/">
#          <img alt="songkick" height="26" src="//assets.sk-static.com/assets/images/nw/furniture/songkick-logo.1ca94a866234b39c08944cbc38423d06.svg" width="90"/>
#         </a>
#        </li>
#        <li class="nav-item metro-area menu hover-for-touch">
#         <a data-analytics-category="navigation" data-analytics-label="metro_area" href="/metro_areas/1409-us-washington" title="Washington concerts">
#          Washington concerts
#         </a>
#         <div class="menu-content">
#          <a data-analytics-category="navigation" data-analytics-label="popular_tickets" href="/metro_areas/1409-us-washington">
#           <span>
#            Popular tickets in Washington
#           </span>
#          </a>
#          <a class="repeat" data-analytics-category="navigation" data-analytics-label="metro_area" href="/metro_areas/1409-us-washington">
#           Washington concerts
#          </a>
#          <ul class="listing">
#           <li class="event">
#            <a class="col" data-analytics-category="navigation" data-analytics-label="metro_area_popular_ticket" href="/concerts/37832864-khalid-at-capital-one-arena">
#             <img alt="Khalid live" class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/894756/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#             <span class="col">
#              <span class="name">
#               Khalid
#              </span>
#              <br/>
#              <span class="venue">
#               Capital One Arena
#              </span>
#             </span>
#            </a>
#           </li>
#           <li class="event">
#            <a class="col" data-analytics-category="navigation" data-analytics-label="metro_area_popular_ticket" href="/concerts/37810759-deadmau5-at-anthem">
#             <img alt="Deadmau5 live" class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/244669/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#             <span class="col">
#              <span class="name">
#               Deadmau5
#              </span>
#              <br/>
#              <span class="venue">
#               The Anthem
#              </span>
#             </span>
#            </a>
#           </li>
#           <li class="event">
#            <a class="col" data-analytics-category="navigation" data-analytics-label="metro_area_popular_ticket" href="/concerts/36826139-rascal-flatts-at-jiffy-lube-live">
#             <img alt="Rascal Flatts live" class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/88395/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#             <span class="col">
#              <span class="name">
#               Rascal Flatts
#              </span>
#              <br/>
#              <span class="venue">
#               Jiffy Lube Live
#              </span>
#             </span>
#            </a>
#           </li>
#           <li class="event">
#            <a class="col" data-analytics-category="navigation" data-analytics-label="metro_area_popular_ticket" href="/concerts/37880674-hot-chip-at-930-club">
#             <img alt="Hot Chip live" class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/256535/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#             <span class="col">
#              <span class="name">
#               Hot Chip
#              </span>
#              <br/>
#              <span class="venue">
#               9:30 Club
#              </span>
#             </span>
#            </a>
#           </li>
#           <li class="event">
#            <a class="col" data-analytics-category="navigation" data-analytics-label="metro_area_popular_ticket" href="/concerts/37501759-jennifer-lopez-at-capital-one-arena">
#             <img alt="Jennifer Lopez live" class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/95022/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#             <span class="col">
#              <span class="name">
#               Jennifer Lopez
#              </span>
#              <br/>
#              <span class="venue">
#               Capital One Arena
#              </span>
#             </span>
#            </a>
#           </li>
#           <li class="event">
#            <a class="col" data-analytics-category="navigation" data-analytics-label="metro_area_popular_ticket" href="/concerts/37872739-elvis-costello-and-the-imposters-at-anthem">
#             <img alt="Elvis Costello &amp; The Imposters live" class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/463301/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#             <span class="col">
#              <span class="name">
#               Elvis Costello &amp; The Imposters
#              </span>
#              <br/>
#              <span class="venue">
#               The Anthem
#              </span>
#             </span>
#            </a>
#           </li>
#           <li class="event">
#            <a class="col" data-analytics-category="navigation" data-analytics-label="metro_area_popular_ticket" href="/concerts/37950149-sara-bareilles-at-anthem">
#             <img alt="Sara Bareilles live" class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/390985/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#             <span class="col">
#              <span class="name">
#               Sara Bareilles
#              </span>
#              <br/>
#              <span class="venue">
#               The Anthem
#              </span>
#             </span>
#            </a>
#           </li>
#           <li class="event">
#            <a class="col" data-analytics-category="navigation" data-analytics-label="metro_area_popular_ticket" href="/concerts/37900869-celine-dion-at-capital-one-arena">
#             <img alt="Celine Dion live" class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/76025/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#             <span class="col">
#              <span class="name">
#               Celine Dion
#              </span>
#              <br/>
#              <span class="venue">
#               Capital One Arena
#              </span>
#             </span>
#            </a>
#           </li>
#           <li class="event">
#            <a class="col" data-analytics-category="navigation" data-analytics-label="metro_area_popular_ticket" href="/concerts/37852864-carly-rae-jepsen-at-fillmore-silver-spring">
#             <img alt="Carly Rae Jepsen live" class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/2524811/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#             <span class="col">
#              <span class="name">
#               Carly Rae Jepsen
#              </span>
#              <br/>
#              <span class="venue">
#               The Fillmore Silver Spring
#              </span>
#             </span>
#            </a>
#           </li>
#           <li class="event">
#            <a class="col" data-analytics-category="navigation" data-analytics-label="metro_area_popular_ticket" href="/concerts/37898259-lauv-at-anthem">
#             <img alt="Lauv live" class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/8623349/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#             <span class="col">
#              <span class="name">
#               Lauv
#              </span>
#              <br/>
#              <span class="venue">
#               The Anthem
#              </span>
#             </span>
#            </a>
#           </li>
#          </ul>
#          <a data-analytics-category="navigation" data-analytics-label="metro_area_see_all" href="/metro_areas/1409-us-washington">
#           See all Washington concerts
#          </a>
#          <a class="change-location" data-analytics-category="navigation-megadropdown" data-analytics-label="change_location" href="/session/filter_metro_area">
#           (Change location)
#          </a>
#          <br/>
#          <br/>
#          <a data-analytics-category="navigation" data-analytics-label="metro_area_today" href="/metro_areas/1409-us-washington?filters%5BmaxDate%5D=04%2F14%2F2019&amp;filters%5BminDate%5D=04%2F14%2F2019#date-filter-form">
#           Today ·
#          </a>
#          <a data-analytics-category="navigation" data-analytics-label="metro_area_7days" href="/metro_areas/1409-us-washington?filters%5BmaxDate%5D=04%2F21%2F2019&amp;filters%5BminDate%5D=04%2F14%2F2019#date-filter-form">
#           Next 7 days ·
#          </a>
#          <a data-analytics-category="navigation" data-analytics-label="metro_area_month" href="/metro_areas/1409-us-washington?filters%5BmaxDate%5D=05%2F14%2F2019&amp;filters%5BminDate%5D=04%2F14%2F2019#date-filter-form">
#           Next 30 days
#          </a>
#         </div>
#        </li>
#        <li class="nav-item artists menu hover-for-touch">
#         <a data-analytics-category="navigation" data-analytics-label="artists" href="/metro_areas/1409-us-washington#popular-artists-in-metro-area">
#          Artists
#         </a>
#         <div class="menu-content">
#          <ul class="artists-navigation">
#           <li class="col">
#            <a data-analytics-category="navigation" data-analytics-label="popular_artists_metro_area" href="/metro_areas/1409-us-washington#popular-artists-in-metro-area">
#             Popular artists in Washington
#            </a>
#           </li>
#           <li class="col">
#            <a data-analytics-category="navigation" data-analytics-label="trending_artists" href="/leaderboards/trending_artists">
#             Trending artists worldwide
#            </a>
#           </li>
#          </ul>
#          <div class="listing">
#           <ul class="col popular-artists">
#            <li>
#             <a data-analytics-category="navigation" data-analytics-label="artists_popular_artist_metro_area" href="/artists/24672-raheem-devaughn">
#              <img alt="Raheem DeVaughn live." class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/24672/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#              <span class="name">
#               Raheem DeVaughn
#              </span>
#             </a>
#            </li>
#            <li>
#             <a data-analytics-category="navigation" data-analytics-label="artists_popular_artist_metro_area" href="/artists/126229-lalah-hathaway">
#              <img alt="Lalah Hathaway live." class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/126229/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#              <span class="name">
#               Lalah Hathaway
#              </span>
#             </a>
#            </li>
#            <li>
#             <a data-analytics-category="navigation" data-analytics-label="artists_popular_artist_metro_area" href="/artists/151653-kem">
#              <img alt="Kem live." class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/151653/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#              <span class="name">
#               Kem
#              </span>
#             </a>
#            </li>
#            <li>
#             <a data-analytics-category="navigation" data-analytics-label="artists_popular_artist_metro_area" href="/artists/21435-mint-condition">
#              <img alt="Mint Condition live." class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/21435/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#              <span class="name">
#               Mint Condition
#              </span>
#             </a>
#            </li>
#            <li>
#             <a data-analytics-category="navigation" data-analytics-label="artists_popular_artist_metro_area" href="/artists/29915-ledisi">
#              <img alt="Ledisi live." class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/29915/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#              <span class="name">
#               Ledisi
#              </span>
#             </a>
#            </li>
#           </ul>
#           <ul class="col popular-artists">
#            <li>
#             <a data-analytics-category="navigation" data-analytics-label="artists_trending_artist" href="/artists/9902029-murda-beatz">
#              <img alt="Murda Beatz live." class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/9902029/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#              <span class="name">
#               Murda Beatz
#              </span>
#             </a>
#            </li>
#            <li>
#             <a data-analytics-category="navigation" data-analytics-label="artists_trending_artist" href="/artists/9893654-keala-settle">
#              <img alt="Keala Settle live." class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/9893654/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#              <span class="name">
#               Keala Settle
#              </span>
#             </a>
#            </li>
#            <li>
#             <a data-analytics-category="navigation" data-analytics-label="artists_trending_artist" href="/artists/9893659-notd">
#              <img alt="NOTD live." class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/9893659/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#              <span class="name">
#               NOTD
#              </span>
#             </a>
#            </li>
#            <li>
#             <a data-analytics-category="navigation" data-analytics-label="artists_trending_artist" href="/artists/9893684-loren-allred">
#              <img alt="Loren Allred live." class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/9893684/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#              <span class="name">
#               Loren Allred
#              </span>
#             </a>
#            </li>
#            <li>
#             <a data-analytics-category="navigation" data-analytics-label="artists_trending_artist" href="/artists/9893594-tayk">
#              <img alt="Tay-K live." class="artist-profile-image artist" data-src="//images.sk-static.com/images/media/profile_images/artists/9893594/avatar" height="35" src="//assets.sk-static.com/assets/images/default_images/thumb/default-artist.d753c4f267cefff0385f8c0be01cf79d.png" width="35"/>
#              <span class="name">
#               Tay-K
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="tourbox-cta">
#           Get your tour dates seen by one billion fans:
#           <a class="sign-up-as-an-artist" data-analytics-category="navigation" data-analytics-label="sign_up_tourbox" href="//tourbox.songkick.com/?utm_medium=referral&amp;utm_source=songkick.com&amp;utm_campaign=visitor">
#            Sign up as an artist
#           </a>
#          </div>
#         </div>
#        </li>
#        <li class="nav-item about-us">
#         <a data-analytics-category="navigation" data-analytics-label="about_us" href="/info/about?utm_source=songkick.com&amp;utm_medium=referral&amp;utm_campaign=aboutpagetopnav">
#          About us
#         </a>
#        </li>
#        <li class="location">
#         <a data-analytics-category="navigation" data-analytics-label="change_location" href="/session/filter_metro_area">
#          Change location
#         </a>
#        </li>
#       </ul>
#       <li class="sub-nav">
#        <ul>
#         <li class="search">
#          <form accept-charset="UTF-8" action="/search" class="navigation-search-form" data-analytics-category="navigation" data-analytics-label="search" method="get" name="search">
#           <input name="utf8" type="hidden" value="✓"/>
#           <input name="type" type="hidden" value="initial"/>
#           <input class="text navigation-search" name="query" placeholder="Find concerts for any artist or city" type="search" value=""/>
#           <button class="search-button" name="commit" type="submit">
#            <img alt="search" class="navigation-submit" height="15" src="//assets.sk-static.com/assets/images/nw/components/navigation-large-screen/search.af8800530b546ceb49f0d1ff652b9cbe.svg" width="14"/>
#           </button>
#          </form>
#         </li>
#         <li class="login-signup">
#          <a class="signup-link" data-analytics-category="navigation" data-analytics-label="sign_up" data-signup-source="Everything else" href="https://accounts.songkick.com/signup/new?source_product=skweb&amp;login_success_url=https%3A%2F%2Fwww.songkick.com%2Fartists%2F5607218-isaiah-rashad" rel="nofollow">
#           Sign up
#          </a>
#          <a class="login-link" data-analytics-category="navigation" data-analytics-label="log_in" href="https://accounts.songkick.com/session/new?source_product=skweb&amp;login_success_url=https%3A%2F%2Fwww.songkick.com%2Fartists%2F5607218-isaiah-rashad" rel="nofollow">
#           Log in
#          </a>
#         </li>
#        </ul>
#       </li>
#      </li>
#     </ul>
#    </div>
#    <div class="local-navigation">
#     <a data-analytics-category="navigation_small_screen" data-analytics-label="logo" href="/" id="logo">
#      <img alt="Songkick" height="32" src="//assets.sk-static.com/assets/images/nw/components/navigation/header-logo.e09189b0e84d278bd85f0ef3166243cf.png" width="124"/>
#     </a>
#     <ul>
#      <li class="nav-icon main-menu">
#       <a href="#home">
#        <img alt="Show navigation" height="15" src="//assets.sk-static.com/assets/images/nw/components/navigation/local-navigation/navigation-icon.9298db39519a117d653ab64baa8c608e.png" width="22"/>
#       </a>
#      </li>
#      <li class="nav-icon search-nav">
#       <label>
#        <a href="#search">
#         <img alt="search" height="20" src="//assets.sk-static.com/assets/images/nw/components/navigation/local-navigation/search.3a2253b3bba09f3d06d2d7b00bd67293.png" width="20"/>
#        </a>
#       </label>
#      </li>
#      <li class="site-search" id="search">
#       <form accept-charset="UTF-8" action="/search" class="navigation-search-form" data-analytics-category="navigation" data-analytics-label="search" method="get" name="search">
#        <input name="utf8" type="hidden" value="✓">
#         <input name="type" type="hidden" value="initial"/>
#         <input class="text navigation-search" name="query" placeholder="Find concerts for any artist or city" type="search" value=""/>
#         <button class="search-button" name="commit" type="submit">
#          <img alt="search" class="navigation-submit" height="15" src="//assets.sk-static.com/assets/images/nw/components/navigation-large-screen/search.af8800530b546ceb49f0d1ff652b9cbe.svg" width="14"/>
#         </button>
#        </input>
#       </form>
#      </li>
#      <li class="home nav" id="home">
#       <a data-analytics-category="navigation" data-analytics-label="home" href="/">
#        Home
#       </a>
#      </li>
#      <li class="nav">
#       <a data-analytics-category="navigation" data-analytics-label="metro_area" href="/metro_areas/1409-us-washington">
#        Washington concerts
#       </a>
#      </li>
#      <li class="nav">
#       <a data-analytics-category="navigation" data-analytics-label="change_location" href="/session/filter_metro_area">
#        Change location
#       </a>
#      </li>
#      <li>
#       <a data-analytics-catigory="navigation" data-analytics-label="popular_artists" href="/leaderboards/popular_artists">
#        Popular artists
#       </a>
#      </li>
#      <li class="nav">
#       <a data-analytics-category="navigation" data-analytics-label="about_us" href="/info/about?utm_source=songkick.com&amp;utm_medium=referral&amp;utm_campaign=aboutpagetopnav">
#        About us
#       </a>
#      </li>
#      <li class="login">
#       <a data-analytics_category="navigation" data-analytics_label="log_in" href="https://accounts.songkick.com/session/new?source_product=skweb&amp;login_success_url=https%3A%2F%2Fwww.songkick.com%2Fartists%2F5607218-isaiah-rashad">
#        <img alt="Log in" height="14" src="//assets.sk-static.com/assets/images/nw/components/navigation/user.4933483348b2a9784f0513184ac52b9f.svg"/>
#        Log in to your account
#       </a>
#      </li>
#      <li class="signup">
#       <a data-analytics-category="navigation" data-analytics-label="sign_up" href="https://accounts.songkick.com/signup/new?source_product=skweb&amp;login_success_url=https%3A%2F%2Fwww.songkick.com%2Fartists%2F5607218-isaiah-rashad">
#        Sign up
#       </a>
#      </li>
#     </ul>
#    </div>
#    <script type="text/javascript">
#     new Songkick.Component.NavigationSmallScreen();
#    </script>
#   </div>
#   <div class="sticky-container">
#    <div class="artist-header">
#     <div class="ad-container-leaderboard-artist ad-primary-desktop">
#      <div id="div-gpt-ad-1542383467143-0">
#      </div>
#     </div>
#     <div class="row component brief">
#      <div class="col-8 primary">
#       <h1 class="h0 image-padding word-break">
#        Isaiah Rashad
#       </h1>
#       <ul>
#        <li class="ontour">
#         On tour:
#         <strong>
#          no
#         </strong>
#        </li>
#        <li class="calendar">
#         Upcoming 2019 concerts:
#         <strong>
#          none
#         </strong>
#        </li>
#       </ul>
#       <div class="signup-cta-container">
#        <h4>
#         Be the first to know when they tour near you.
#        </h4>
#        <p>
#         155,202 fans get concert alerts for this artist.
#        </p>
#        <div class="track-artist">
#         <div class="tracking">
#          <form accept-charset="UTF-8" action="/trackings" class="app-store-redirect" data-analytics-action="artist:off_tour:cta_button" data-analytics-category="signup_cta" data-analytics-label="5607218" data-stop-tracking-text="Yes, please notify me" data-tracking-text="Yes, please notify me" method="post">
#           <input name="utf8" type="hidden" value="✓">
#            <input name="authenticity_token" type="hidden" value="MDD2EoE+UyQWqlzy0f+dfhXFPohZTsvrmlUZir/0hts5i117YXBPmfaRd9hdJT3lvbYCzxaPZpWo9AMpltRlxw==">
#             <input name="relationship_type" type="hidden" value="concerts"/>
#             <input name="tracking_context" type="hidden" value="default"/>
#             <input name="subject_id" type="hidden" value="5607218"/>
#             <input name="subject_type" type="hidden" value="Artist"/>
#             <input name="success_url" type="hidden" value="/artists/5607218-isaiah-rashad"/>
#             <input name="app_store_redirect_url" type="hidden" value=""/>
#             <button class="artist signup-cta" type="submit" value="Yes, please notify me">
#              Yes, please notify me
#             </button>
#            </input>
#           </input>
#          </form>
#         </div>
#        </div>
#        <div class="app-store-buttons">
#         <a class="app-store-button" data-analytics-action="artist:off_tour:app_store_bt" data-analytics-category="signup_cta" data-analytics-label="5607218" href="https://itunes.apple.com/us/app/apple-store/id438690886?ct=skweb%3Aartist%3Aoff_tour%3Aapp_store_bt&amp;mt=8&amp;pt=307660">
#          <img alt="Available on the App Store" class="store-button" src="//assets.sk-static.com/assets/images/nw/components/artist-off-tour-mobile/app-store-icon.4f7b60de690d19238b40bd59bc4f2a83.svg"/>
#         </a>
#         <a class="google-play-button" data-analytics-action="artist:off_tour:app_store_bt" data-analytics-category="signup_cta" data-analytics-label="5607218" href="https://play.google.com/store/apps/details?id=com.songkick&amp;referrer=utm_campaign%3Dartist%253Aoff_tour%253Aapp_store_bt%26utm_medium%3D%26utm_source%3Dskweb">
#          <img alt="Available on the Play Store" class="store-button" src="//assets.sk-static.com/assets/images/nw/components/artist-off-tour-mobile/play-store-icon.f9aea5dd0b3130188b858f8cd4800697.svg"/>
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="col-4 profile-picture-wrap">
#       <a class="media-link" data-analytics-category="artist_brief" data-analytics-label="profile_image" href="/images/22253056" rel="nofollow">
#        <img alt="Isaiah Rashad live." class="artist artist-profile-image" height="300" src="//images.sk-static.com/images/media/profile_images/artists/5607218/huge_avatar" width="300"/>
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="container">
#     <div class="row">
#      <div class="col-8 primary">
#       <div class="component similar-artists-events carousel paginated">
#        <h2>
#         Similar artists with upcoming concerts
#        </h2>
#        <div class="carousel-list" data-analytics_category="similar_artists_events" data-per-page-count="4">
#         <div class="carousel-item">
#          <a class="artist-image" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/36637659-smino-at-fillmore-silver-spring">
#           <img alt="Smino, EarthGang, and Phoelix at The Fillmore Silver Spring (07 May 19)" class="artist" height="140" src="//images.sk-static.com/images/media/profile_images/artists/8668659/large_avatar" width="140"/>
#          </a>
#          <div class="carousel-item-name">
#           <a class="event-details" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/artists/8668659-smino">
#            Smino
#           </a>
#          </div>
#          <div class="carousel-item-details">
#           <a data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/36637659-smino-at-fillmore-silver-spring">
#            Tue 07 May 2019
#            <br/>
#            <span class="event-details">
#             The Fillmore Silver Spring
#            </span>
#            <span class="event-details">
#             Silver Spring, MD, US
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="carousel-item">
#          <a class="artist-image" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37188424-jid-at-fillmore-silver-spring">
#           <img alt="JID and Saba at The Fillmore Silver Spring (03 May 19)" class="artist" height="140" src="//images.sk-static.com/images/media/profile_images/artists/660883/large_avatar" width="140"/>
#          </a>
#          <div class="carousel-item-name">
#           <a class="event-details" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/artists/660883-jid">
#            JID
#           </a>
#          </div>
#          <div class="carousel-item-details">
#           <a data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37188424-jid-at-fillmore-silver-spring">
#            Fri 03 May 2019
#            <br/>
#            <span class="event-details">
#             The Fillmore Silver Spring
#            </span>
#            <span class="event-details">
#             Silver Spring, MD, US
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="carousel-item">
#          <a class="artist-image" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/festivals/692324-broccoli-city/id/37233064-broccoli-city-festival-2019">
#           <img alt="Broccoli City Festival 2019" class="artist" height="140" src="//images.sk-static.com/images/media/profile_images/events/37233064/large_avatar" width="140"/>
#          </a>
#          <div class="carousel-item-name">
#           <a class="event-details" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/artists/65557-lil-wayne">
#            Lil Wayne
#           </a>
#          </div>
#          <div class="carousel-item-details">
#           <a data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/festivals/692324-broccoli-city/id/37233064-broccoli-city-festival-2019">
#            Sat 27 Apr 2019
#            <br/>
#            <span class="event-details">
#             Broccoli City Festival 2019
#            </span>
#            <span class="event-details">
#             Hyattsville, MD, US
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="carousel-item">
#          <a class="artist-image" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/festivals/692324-broccoli-city/id/36780129-broccoli-city-festival-2019">
#           <img alt="Broccoli City Festival 2019" class="artist" height="140" src="//images.sk-static.com/images/media/profile_images/events/36780129/large_avatar" width="140"/>
#          </a>
#          <div class="carousel-item-name">
#           <a class="event-details" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/artists/65557-lil-wayne">
#            Lil Wayne
#           </a>
#          </div>
#          <div class="carousel-item-details">
#           <a data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/festivals/692324-broccoli-city/id/36780129-broccoli-city-festival-2019">
#            Sat 27 Apr 2019
#            <br/>
#            <span class="event-details">
#             Broccoli City Festival 2019
#            </span>
#            <span class="event-details">
#             Landover, MD, US
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="carousel-item">
#          <a class="artist-image" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37181164-kali-uchis-at-anthem">
#           <img alt="Kali Uchis and Jorja Smith at The Anthem (28 Apr 19)" class="artist" height="140" src="//images.sk-static.com/images/media/profile_images/artists/7338694/large_avatar" width="140"/>
#          </a>
#          <div class="carousel-item-name">
#           <a class="event-details" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/artists/7338694-kali-uchis">
#            Kali Uchis
#           </a>
#          </div>
#          <div class="carousel-item-details">
#           <a data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37181164-kali-uchis-at-anthem">
#            Sun 28 Apr 2019
#            <br/>
#            <span class="event-details">
#             The Anthem
#            </span>
#            <span class="event-details">
#             Washington, DC, US
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="carousel-item">
#          <a class="artist-image" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37823089-asap-ferg-at-comcast-center">
#           <img alt="A$AP Ferg at Comcast Center (03 May 19) with Jessie Reyez" class="artist" height="140" src="//images.sk-static.com/images/media/profile_images/artists/5612553/large_avatar" width="140"/>
#          </a>
#          <div class="carousel-item-name">
#           <a class="event-details" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/artists/5612553-asap-ferg">
#            A$AP Ferg
#           </a>
#          </div>
#          <div class="carousel-item-details">
#           <a data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37823089-asap-ferg-at-comcast-center">
#            Fri 03 May 2019
#            <br/>
#            <span class="event-details">
#             Comcast Center
#            </span>
#            <span class="event-details">
#             College Park, MD, US
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="carousel-item">
#          <a class="artist-image" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37061919-billie-eilish-at-anthem">
#           <img alt="Billie Eilish at The Anthem (20 Jun 19) with Denzel Curry" class="artist" height="140" src="//images.sk-static.com/images/media/profile_images/artists/8913479/large_avatar" width="140"/>
#          </a>
#          <div class="carousel-item-name">
#           <a class="event-details" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/artists/8913479-billie-eilish">
#            Billie Eilish
#           </a>
#          </div>
#          <div class="carousel-item-details">
#           <a data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37061919-billie-eilish-at-anthem">
#            Thu 20 Jun 2019
#            <br/>
#            <span class="event-details">
#             The Anthem
#            </span>
#            <span class="event-details">
#             Washington, DC, US
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="carousel-item">
#          <a class="artist-image" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37002009-lolo-zouai-at-songbyrd-music-house">
#           <img alt="Lolo Zouaï at Songbyrd Music House (27 Apr 19) with Jean Deaux" class="artist" height="140" src="//images.sk-static.com/images/media/profile_images/artists/9465904/large_avatar" width="140"/>
#          </a>
#          <div class="carousel-item-name">
#           <a class="event-details" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/artists/9465904-lolo-zouai">
#            Lolo Zouaï
#           </a>
#          </div>
#          <div class="carousel-item-details">
#           <a data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37002009-lolo-zouai-at-songbyrd-music-house">
#            Sat 27 Apr 2019
#            <br/>
#            <span class="event-details">
#             Songbyrd Music House
#            </span>
#            <span class="event-details">
#             Washington, DC, US
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="carousel-item">
#          <a class="artist-image" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/35507494-sevs-reunion-at-union-stage">
#           <img alt="SEV's Reunion and Jimmie's Chicken Shack at Union Stage (27 Apr 19) with Jean Deaux" class="artist" height="140" src="//images.sk-static.com/images/media/profile_images/artists/9929964/large_avatar" width="140"/>
#          </a>
#          <div class="carousel-item-name">
#           <a class="event-details" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/artists/9929964-sevs-reunion">
#            SEV's Reunion
#           </a>
#          </div>
#          <div class="carousel-item-details">
#           <a data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/35507494-sevs-reunion-at-union-stage">
#            Sat 27 Apr 2019
#            <br/>
#            <span class="event-details">
#             Union Stage
#            </span>
#            <span class="event-details">
#             Washington, DC, US
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="carousel-item">
#          <a class="artist-image" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37174499-kodak-black-at-anthem">
#           <img alt="Kodak Black at The Anthem (24 Apr 19) with 147 CalBoy, Sniper Gang Music, 22Gz, and Roddy Ricch" class="artist" height="140" src="//images.sk-static.com/images/media/profile_images/artists/8680734/large_avatar" width="140"/>
#          </a>
#          <div class="carousel-item-name">
#           <a class="event-details" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/artists/8680734-kodak-black">
#            Kodak Black
#           </a>
#          </div>
#          <div class="carousel-item-details">
#           <a data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37174499-kodak-black-at-anthem">
#            Wed 24 Apr 2019
#            <br/>
#            <span class="event-details">
#             The Anthem
#            </span>
#            <span class="event-details">
#             Washington, DC, US
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="carousel-item">
#          <a class="artist-image" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37129519-nas-at-wolf-trap">
#           <img alt="Nas at Wolf Trap (14 Jul 19) with National Symphony Orchestra" class="artist" height="140" src="//images.sk-static.com/images/media/profile_images/artists/38697/large_avatar" width="140"/>
#          </a>
#          <div class="carousel-item-name">
#           <a class="event-details" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/artists/38697-nas">
#            Nas
#           </a>
#          </div>
#          <div class="carousel-item-details">
#           <a data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37129519-nas-at-wolf-trap">
#            Sun 14 Jul 2019
#            <br/>
#            <span class="event-details">
#             Wolf Trap
#            </span>
#            <span class="event-details">
#             Vienna, VA, US
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="carousel-item">
#          <a class="artist-image" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37792899-kari-faux-at-songbyrd-music-house">
#           <img alt="Kari Faux at Songbyrd Music House (27 May 19)" class="artist" height="140" src="//images.sk-static.com/images/media/profile_images/artists/4956523/large_avatar" width="140"/>
#          </a>
#          <div class="carousel-item-name">
#           <a class="event-details" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/artists/4956523-kari-faux">
#            Kari Faux
#           </a>
#          </div>
#          <div class="carousel-item-details">
#           <a data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37792899-kari-faux-at-songbyrd-music-house">
#            Mon 27 May 2019
#            <br/>
#            <span class="event-details">
#             Songbyrd Music House
#            </span>
#            <span class="event-details">
#             Washington, DC, US
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="carousel-item">
#          <a class="artist-image" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37404294-method-man-and-redman-at-howard-theatre">
#           <img alt="Method Man &amp; Redman at Howard Theatre (18 Apr 19)" class="artist" height="140" src="//images.sk-static.com/images/media/profile_images/artists/466926/large_avatar" width="140"/>
#          </a>
#          <div class="carousel-item-name">
#           <a class="event-details" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/artists/466926-method-man-and-redman">
#            Method Man &amp; Redman
#           </a>
#          </div>
#          <div class="carousel-item-details">
#           <a data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37404294-method-man-and-redman-at-howard-theatre">
#            Thu 18 Apr 2019
#            <br/>
#            <span class="event-details">
#             Howard Theatre
#            </span>
#            <span class="event-details">
#             Washington, DC, US
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="carousel-item">
#          <a class="artist-image" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37977619-flume-at-red-rocks-amphitheatre">
#           <img alt="Flume at Red Rocks Amphitheatre (07 Aug 19) with jpegmafia and Slowthai" class="artist" height="140" src="//images.sk-static.com/images/media/profile_images/artists/3645486/large_avatar" width="140"/>
#          </a>
#          <div class="carousel-item-name">
#           <a class="event-details" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/artists/3645486-flume">
#            Flume
#           </a>
#          </div>
#          <div class="carousel-item-details">
#           <a data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37977619-flume-at-red-rocks-amphitheatre">
#            Wed 07 Aug 2019
#            <br/>
#            <span class="event-details">
#             Red Rocks Amphitheatre
#            </span>
#            <span class="event-details">
#             Morrison, CO, US
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="carousel-item">
#          <a class="artist-image" data-analytics-category="similar_artists_events" data-analytics-label="parent_artist_id_5607218" href="/concerts/37862784-jid-at-regency-ballroom">
#           <img alt="JID at The Regency Ballroom (05 Jun 19) with Saba" class="artist" height="140" src="//images.sk-static.com/images/media/profile_images/artists/660883/large_avatar" width="140"/>
#          </a>
#          <div class="carousel-item-name">
# ...
#              <input name="subject_id" type="hidden" value="134055"/>
#              <input name="subject_type" type="hidden" value="Artist"/>
#              <input name="success_url" type="hidden" value="/artists/5607218-isaiah-rashad"/>
#              <input name="app_store_redirect_url" type="hidden" value=""/>
#              <button class="artist track" type="submit" value="Track artist">
#               Track artist
#              </button>
#             </input>
#            </input>
#           </form>
#          </div>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="microformat">
#     <script type="application/ld+json">
#      [{"@context":"http://schema.org","@type":"MusicGroup","name":"Isaiah Rashad","url":"https://www.songkick.com/artists/5607218-isaiah-rashad?utm_medium=organic\u0026utm_source=microformat","image":"https://images.sk-static.com/images/media/profile_images/artists/5607218/card_avatar","logo":"https://images.sk-static.com/images/media/profile_images/artists/5607218/card_avatar","interactionCount":"155202 UserLikes","review":{"@type":"Review","reviewBody":"he's tde so it's to be expected, but he nonetheless killed it. hit all the right notes.\r\n\r\nopening jay IDK seemed a little unpolished, and polish is ultimately what it seems like he's going for, so it was a bit of a different feel from wop.\r\n\r\npersonally, i think it was one of the better shows i'd seen in a while. whenever you come out of a performance and it changes the way you go about your day in some way, shape or form, you know something real happened.\r\n\r\ngood people, good vibes, great venue. sinclair is the best in boston and that's binnown.\r\n\r\nseeing him again in tampa. will be interesting to see how he looks in a different light- but good looks so far","author":"jsanderson"}}]
#     </script>
#    </div>
#   </div>
#   <div class="footer-container">
#    <div class="container footer" id="footer">
#     <div class="row">
#      <div class="col-3">
#       <ul>
#        <li>
#         <a href="/">
#          Home
#         </a>
#        </li>
#        <li>
#         <a href="/info/about" rel="nofollow">
#          About us
#         </a>
#        </li>
#        <li>
#         <a href="/app" rel="nofollow">
#          Get the app
#         </a>
#        </li>
#        <li>
#         <a href="/blog" rel="nofollow">
#          Blog
#         </a>
#        </li>
#        <li>
#         <a href="/jobs" rel="nofollow">
#          Jobs
#         </a>
#        </li>
#        <li>
#         <a href="http://support.songkick.com/">
#          Help &amp; FAQ
#         </a>
#        </li>
#        <li>
#         <a href="/leaderboards/popular_artists">
#          Most popular charts
#         </a>
#        </li>
#        <li>
#         <a href="/festivals">
#          Festivals
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col-3">
#       <ul>
#        <li>
#         <a href="//tourbox.songkick.com/?utm_medium=referral&amp;utm_source=songkick.com&amp;utm_campaign=tourboxforartists">
#          Tourbox for artists
#         </a>
#        </li>
#        <li>
#         <a href="/developer">
#          <abbr>
#           API
#          </abbr>
#          information
#         </a>
#        </li>
#        <li>
#         <a href="/design/brand/mission" rel="nofollow">
#          Brand guidelines
#         </a>
#        </li>
#        <li>
#         <a href="/info/guidelines" rel="nofollow">
#          Community guidelines
#         </a>
#        </li>
#        <li>
#         <a href="/info/terms" rel="nofollow">
#          Terms of use
#         </a>
#        </li>
#        <li>
#         <a href="/info/privacy" rel="nofollow">
#          Privacy policy
#         </a>
#        </li>
#        <li>
#         <a href="/info/privacy#other-information" rel="nofollow">
#          Ad &amp; cookies policy
#         </a>
#        </li>
#        <li>
#         <a href="/info/security" rel="nofollow">
#          Security
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="col-6">
#       <div class="tourbox-cta">
#        <p>
#         Get your tour dates seen everywhere.
#        </p>
#        <a class="sign-up-as-an-artist" data-analytics-category="navigation" data-analytics-label="sign_up_tourbox" href="//tourbox.songkick.com/?utm_medium=referral&amp;utm_source=songkick.com&amp;utm_campaign=visitor">
#         Sign up as an artist
#        </a>
#       </div>
#       <div class="social-container">
#        <ul class="social-icons">
#         <li>
#          <a href="https://twitter.com/songkick">
#           <img alt="Twitter" height="18" src="//assets.sk-static.com/assets/images/nw/furniture/icons/twitter.c23b96299cc4c969747eb1d55aa6e875.png" width="22"/>
#           <span>
#            Follow us.
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="http://www.facebook.com/songkick">
#           <img alt="Facebook" height="18" src="//assets.sk-static.com/assets/images/nw/furniture/icons/facebook.953cd3b882b8602746d41356ebec6b59.png" width="18"/>
#           <span>
#            Like us.
#           </span>
#          </a>
#         </li>
#         <li>
#          <span>
#           But we really hope you love us.
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- start Mixpanel -->
#   <!-- end Mixpanel -->
#   <script type="text/javascript">
#    !function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");
#   </script>
#   <script src="//www.google-analytics.com/cx/api.js">
#   </script>
#   <script>
#    // Set experoment variation
# cxApi.setChosenVariation(CX_VARIATION_ID, CX_EXPERIMENT_ID);
#    // Load Google Analytics
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#     var gaKey = 'UA-2610254-1';
#     ga('create', gaKey, 'auto', {'allowLinker': true});
#     ga('require', 'linker');
#     ga('linker:autoLink', ['accounts.songkick.com']);
#   </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.7.2/jquery.js">
#   </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jqueryui/1.8.17/jquery-ui.min.js">
#   </script>
#   <script src="//connect.facebook.net/en_US/sdk.js">
#   </script>
#   <script src="//assets.sk-static.com/assets/helpers.f1062c1bf60a1a5f6b01.js" type="text/javascript">
#   </script>
#   <script src="//assets.sk-static.com/assets/shared_components.0b64164e027956468e86.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    Songkick.EventBus.bind('app:initialize', function() {
#       $.cookie('exp_showed_offtour_artist_modal', true, { path: '/'});
#       $(document).on('click', 'a.ticket-vendor', function(e) {
#         Songkick.EventBus.trigger('ui:click', { category: 'tmp_growth_team_ticket_vendor',
#         action: 'logged_out_click',
#         label: $(this).data('event-id').toString(),
#         value: $(this).data('analytics-value')});
#       });
#
#       new Songkick.Component.AcquisitionHookStickyFooter($('.best-bet-box'), $('.artist-sticky-footer'));
#     });
#       Songkick.EventBus.bind('app:initialize', function(config) {
#         var modal = new Songkick.Component.Modal({
#           analytics_category: 'signup_cta',
#           analytics_label: '5607218',
#           analytics_action_prefix: 'artist:post_tv_click',
#           cookie_key: 'vendor-click-cta',
#           modal_class: 'vendor-signup-cta-container',
#           component: '<div class="top-area">  <button class="close-widget close">    <img src="//assets.sk-static.com/assets/images/nw/components/vendor-click-signup-cta/close.092c782cca3f305ea940931498ca9583.svg" alt="Close" height="12" width="12">  </button>    <img alt="Isaiah Rashad live." width="70" height="70" class="artist artist-profile-image" src="//images.sk-static.com/images/media/profile_images/artists/5607218/large_avatar" />  <h2>Still searching for Isaiah Rashad tickets?</h2>  <p class="be-the-first-to-know">Be the first to know about tickets in the future.</p>  <p class="artist-trackings">155,202 other fans want alerts for this artist.</p></div><div class="bottom-area">  <div class="buttons">    <div class="tracking">  <form data-analytics-category="signup_cta" data-analytics-action="artist:post_tv_click:cta_button" data-analytics-label="5607218" data-tracking-text="Yes, please notify me" data-stop-tracking-text="Yes, please notify me" class="app-store-redirect" action="/trackings" accept-charset="UTF-8" method="post"><input name="utf8" type="hidden" value="&#x2713;" /><input type="hidden" name="authenticity_token" value="prd38ORuUo5OQYAJs6+XIWbF4cHNiRdh5G6uilz/S/OvDNyZBCBOM656qyM/dTe6zrbdhoJIuh/Wz7Qpdd+o7w==" />    <input type="hidden" name="relationship_type" value="concerts">    <input type="hidden" name="tracking_context" value="vendor">    <input type="hidden" name="subject_id" value="5607218">    <input type="hidden" name="subject_type" value="Artist">    <input type="hidden" name="success_url" value="/artists/5607218-isaiah-rashad">    <input type="hidden" name="app_store_redirect_url" value="">    <button type="submit" class="artist signup-cta" value="Yes, please notify me">Yes, please notify me</button></form></div>    <a href="https://itunes.apple.com/us/app/apple-store/id438690886?ct=skweb%3Aartist%3Apost_tv_click%3Aapp_store_bt&amp;mt=8&amp;pt=307660" class="app-store-button" data-analytics-category="signup_cta" data-analytics-action="artist:post_tv_click:app_store_bt" data-analytics-label="5607218">      <img src="//assets.sk-static.com/assets/images/nw/components/artist-off-tour-mobile/app-store-icon.4f7b60de690d19238b40bd59bc4f2a83.svg" alt="Available on the App Store" class="store-button">    </a>    <a href="https://play.google.com/store/apps/details?id=com.songkick&amp;referrer=utm_campaign%3Dartist%253Apost_tv_click%253Aapp_store_bt%26utm_medium%3D%26utm_source%3Dskweb" class="google-play-button" data-analytics-category="signup_cta" data-analytics-action="artist:post_tv_click:app_store_bt" data-analytics-label="5607218">      <img src="//assets.sk-static.com/assets/images/nw/components/artist-off-tour-mobile/play-store-icon.f9aea5dd0b3130188b858f8cd4800697.svg" alt="Available on the Play Store" class="store-button">    </a>  </div>  <a class="close-message">I don’t want to hear about tickets</a></div>'
#         });
#         $('body').on('click', 'a.ticket-vendor.third-party',
#           function(e) { modal.show(modal);});
#       });
#   </script>
#   <script type="text/javascript">
#    (function(e,a){if(!a.__SV){var b=window;try{var c,l,i,j=b.location,g=j.hash;c=function(a,b){return(l=a.match(RegExp(b+"=([^&]*)")))?l[1]:null};g&&c(g,"state")&&(i=JSON.parse(decodeURIComponent(c(g,"state"))),"mpeditor"===i.action&&(b.sessionStorage.setItem("_mpcehash",g),history.replaceState(i.desiredHash||"",e.title,j.pathname+j.search)))}catch(m){}var k,h;window.mixpanel=a;a._i=[];a.init=function(b,c,f){function e(b,a){var c=a.split(".");2==c.length&&(b=b[c[0]],a=c[1]);b[a]=function(){b.push([a].concat(Array.prototype.slice.call(arguments,
#       0)))}}var d=a;"undefined"!==typeof f?d=a[f]=[]:f="mixpanel";d.people=d.people||[];d.toString=function(b){var a="mixpanel";"mixpanel"!==f&&(a+="."+f);b||(a+=" (stub)");return a};d.people.toString=function(){return d.toString(1)+".people (stub)"};k="disable time_event track track_pageview track_links track_forms register register_once alias unregister identify name_tag set_config reset people.set people.set_once people.increment people.append people.union people.track_charge people.clear_charges people.delete_user".split(" ");
#       for(h=0;h<k.length;h++)e(d,k[h]);a._i.push([b,c,f])};a.__SV=1.2;b=e.createElement("script");b.type="text/javascript";b.async=!0;b.src="undefined"!==typeof MIXPANEL_CUSTOM_LIB_URL?MIXPANEL_CUSTOM_LIB_URL:"file:"===e.location.protocol&&"//cdn.mxpnl.com/libs/mixpanel-2-latest.min.js".match(/^\/\//)?"https://cdn.mxpnl.com/libs/mixpanel-2-latest.min.js":"//cdn.mxpnl.com/libs/mixpanel-2-latest.min.js";c=e.getElementsByTagName("script")[0];c.parentNode.insertBefore(b,c)}})(document,window.mixpanel||[]);
#
#       mixpanel.init("854b86dd364733860c702c3f38c2cb56");
#       mixpanel.identify("ddb24ac3-0000-4000-8000-000083f5fe23");
#       Songkick.EventBus.bind('app:initialize', function(){
#         Songkick.EventBus.trigger('app:mixpanel:ready');
#       });
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
#   var google_conversion_id = 964669843;
#   var google_custom_params = window.google_tag_params;
#   var google_remarketing_only = true;
#   /* ]]> */
#   </script>
#   <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
#   </script>
#   <noscript>
#    <div style="display:inline;">
#     <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/964669843/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1">
#     </img>
#    </div>
#   </noscript>
#   <script type="text/javascript">
#    sendDmpAnalytics = true;
#     digitalData={"settings":{"reportSuites":"wmg,wmgsongkick"},"page":{"pageInfo":{"pageName":"Songkick:Isaiah Rashad:Artist:Home","server":"Songkick:Site","platform":"SKWeb"},"category":{"primaryCategory":"Songkick:Isaiah Rashad:Artist:Home","pageType":"Songkick:Artist:Home"}},"content":{"artist":"Isaiah Rashad","label":"Songkick"},"user":{"profile":{"profileID":null}}};
#   </script>
#   <script src="//assets.sk-static.com/javascripts/songkick/analytics/dmp-visitor-api.js">
#   </script>
#   <script src="//assets.sk-static.com/javascripts/songkick/analytics/dmp-app-measurement.js">
#   </script>
#   <script type="text/javascript">
#    Songkick.Facebook.init(
#       "308540029359",
#       ["email", "public_profile", "user_friends", "user_likes"],
#       ["email", "public_profile", "user_friends", "user_likes", "publish_actions"],
#       {events: Songkick.EventBus}
#     );
#   </script>
#   <script type="text/javascript">
#    var _qevents = _qevents || [];
#
#     (function() {
#     var elem = document.createElement('script');
#     elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
#     elem.async = true;
#     elem.type = "text/javascript";
#     var scpt = document.getElementsByTagName('script')[0];
#     scpt.parentNode.insertBefore(elem, scpt);
#     })();
#
#     _qevents.push({
#     qacct:"p-73t-O7FWprUTo"
#     });
#   </script>
#   <noscript>
#    <div style="display:none;">
#     <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-73t-O7FWprUTo.gif" width="1">
#     </img>
#    </div>
#   </noscript>
#   <script src="//assets.sk-static.com/assets/ads.fe64ef6eb5cd8c38d709.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    Songkick.EventBus.bind('app:initialize', function() {
#       googletag = window.googletag || {};
#       googletag.cmd = window.googletag.cmd || [];
#       var targetingTags = {"artists":["isaiah rashad"]};
#       new Songkick.Component.Ads(googletag, apstag, targetingTags);
#     });
#   </script>
#   <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
#   </script>
#   <script type="text/javascript">
#    SK.logged_in_user = {
#     id:null,
#     analyticsUserType: 'visitor'
#   };
#
#     Songkick.EventBus.bind('app:initialize', function() {
#       Songkick.EventBus.trigger('ui:view', {"category":"artist_page","action":"view_off_tour","label":"no_upcoming_events"});
#     });
#
#   var features = {};
#   Songkick.EventBus.trigger('app:initialize', {
#     events: Songkick.EventBus,
#     features: features,
#     promoteNativeApp: false,
#     mobileSignupRedirectUrl: '',
#     mobileAnalyticsEnabled: false,
#   });
#   </script>
#  </body>
# </html>

# %%
#soup.find_all(['isaiah', 'div'])
soup.find_all('Capital')
# Out:
# []

# %%
import re
soup.find_all(re.compile("isaiah"))
# Out:
# []
